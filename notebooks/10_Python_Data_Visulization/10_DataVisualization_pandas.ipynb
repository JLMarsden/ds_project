# %%
import seaborn as sns
import numpy  as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
 #1. Get the folder where your current notebook is saved
notebook_dir = Path.cwd()

# 2. Go up the folder tree to a shared folder (e.g., up 1 level)
# Use .parent to go up one level, or .parent.parent to go up two levels
root_dir = notebook_dir.parent 

# 3. Build the path to the target folder and file
file_path_df1 = root_dir / "data" / "processed" / "df1"
file_path_df2 = root_dir / "data" / "processed" / "df2"
print(file_path_df1)
# Out:
# /Users/johnmarsden/Documents/DS_Projects/ds_project/data/processed/df1

# %%
df1 = pd.read_csv(file_path_df1, index_col=0)
df2 = pd.read_csv(file_path_df2, index_col=0)
print(df1)
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1['A'].hist(bins=30)
plt.show()

# %%
df1['A'].plot.hist()
plt.show()

# %%
plt.style.use('ggplot') #Can use styles 
df2.plot.bar()
plt.show()
