# %%
import pandas as pd
import numpy  as np
import seaborn as sb
import matplotlib.pyplot as plt
from pathlib import Path

# %%
 #1. Get the folder where your current notebook is saved
notebook_dir = Path.cwd()

# 2. Go up the folder tree to a shared folder (e.g., up 1 level)
# Use .parent to go up one level, or .parent.parent to go up two levels
root_dir = notebook_dir.parent 

# 3. Build the path to the target folder and file
file_path_lucidworks = root_dir / "data" / "raw" / "LucidworksExtract.csv"
print(file_path_lucidworks)
# Out:
# /Users/johnmarsden/Documents/DS_Projects/ds_project/data/raw/LucidworksExtract.csv

# %%
print(file_path_lucidworks)
# Out:
# /Users/johnmarsden/Documents/DS_Projects/ds_project/data/raw/LucidworksExtract.csv

# %%
df1 = pd.read_csv(file_path_lucidworks, index_col=0)
print(df1)
# Out:
#                                                     BusinessUnit  Unnamed: 2
# Request
# "FCE2U AND shipLocation_s:16011 AND businessUni...          True         NaN
# "7130 AND shipLocation_s:11411 AND businessUnit...          True         NaN
# "CMH-1U-19-LB1 AND shipLocation_s:11411 AND bus...          True         NaN
# "MX- AND shipLocation_s:12304 AND businessUnit_...          True         NaN
# "9a-1104-12* AND salesLocation_s:60682 AND ship...         False         NaN
# ...                                                          ...         ...
# "*:* AND transPartOrFilter:(transactablePart_s:...         False         NaN
# "DCAMJKSME-S1 AND shipLocation_s:15642 AND busi...          True         NaN
# "dcamjk AND shipLocation_s:15642 AND businessUn...          True         NaN
# "DAFP_D1510 AND shipLocation_s:15642 AND busine...          True         NaN
# "ga9520gl* AND salesLocation_s:60001 AND shipLo...         False         NaN
#
# [5239 rows x 2 columns]
